# %%
import koreanize_matplotlib
import numpy as np
import matplotlib.pyplot as plt


# 총 샘플 수 1,000개
N = 1000

# 정사각형 내에서 무작위 점 생성
x = np.random.uniform(-1, 1, N)
y = np.random.uniform(-1, 1, N)

# 원 안에 있는 점 계산
inside_circle = x**2 + y**2 <= 1

# 원주율 근사값 계산
pi_estimate = 4 * np.sum(inside_circle) / N

print(f"원주율 근사치는 {pi_estimate}입니다.")

# 시각화
plt.figure(figsize=(6,6))
plt.scatter(x, y, c=inside_circle, s=1, alpha=0.5)
plt.gca().set_aspect('equal', adjustable='box')
plt.title(f"원주율 근사치: {pi_estimate}")
plt.show()
# Out:
# 원주율 근사치는 3.156입니다.

# %%
# 총 샘플 수 2,500개
N = 2500

# 정사각형 내에서 무작위 점 생성
x = np.random.uniform(-1, 1, N)
y = np.random.uniform(-1, 1, N)

# 원 안에 있는 점 계산
inside_circle = x**2 + y**2 <= 1

# 원주율 근사값 계산
pi_estimate = 4 * np.sum(inside_circle) / N

print(f"원주율 근사치는 {pi_estimate}입니다.")

# 시각화
plt.figure(figsize=(6,6))
plt.scatter(x, y, c=inside_circle, s=1, alpha=0.5)
plt.gca().set_aspect('equal', adjustable='box')
plt.title(f"원주율 근사치: {pi_estimate}")
plt.show()
# Out:
# 원주율 근사치는 3.1056입니다.

# %%
# 총 샘플 수 5,000개
N = 5000

# 정사각형 내에서 무작위 점 생성
x = np.random.uniform(-1, 1, N)
y = np.random.uniform(-1, 1, N)

# 원 안에 있는 점 계산
inside_circle = x**2 + y**2 <= 1

# 원주율 근사값 계산
pi_estimate = 4 * np.sum(inside_circle) / N

print(f"원주율 근사치는 {pi_estimate}입니다.")

# 시각화
plt.figure(figsize=(6,6))
plt.scatter(x, y, c=inside_circle, s=1, alpha=0.5)
plt.gca().set_aspect('equal', adjustable='box')
plt.title(f"원주율 근사치: {pi_estimate}")
plt.show()
# Out:
# 원주율 근사치는 3.1848입니다.

# %%
# 총 샘플 수 10,000개
N = 10000

# 정사각형 내에서 무작위 점 생성
x = np.random.uniform(-1, 1, N)
y = np.random.uniform(-1, 1, N)

# 원 안에 있는 점 계산
inside_circle = x**2 + y**2 <= 1

# 원주율 근사값 계산
pi_estimate = 4 * np.sum(inside_circle) / N

print(f"원주율 근사치는 {pi_estimate}입니다.")

# 시각화
plt.figure(figsize=(6,6))
plt.scatter(x, y, c=inside_circle, s=1, alpha=0.5)
plt.gca().set_aspect('equal', adjustable='box')
plt.title(f"원주율 근사치: {pi_estimate}")
plt.show()
# Out:
# 원주율 근사치는 3.1696입니다.

# %%
# 총 샘플 수 20,000개
N = 20000

# 정사각형 내에서 무작위 점 생성
x = np.random.uniform(-1, 1, N)
y = np.random.uniform(-1, 1, N)

# 원 안에 있는 점 계산
inside_circle = x**2 + y**2 <= 1

# 원주율 근사값 계산
pi_estimate = 4 * np.sum(inside_circle) / N

print(f"원주율 근사치는 {pi_estimate}입니다.")

# 시각화
plt.figure(figsize=(6,6))
plt.scatter(x, y, c=inside_circle, s=1, alpha=0.5)
plt.gca().set_aspect('equal', adjustable='box')
plt.title(f"원주율 근사치: {pi_estimate}")
plt.show()
# Out:
# 원주율 근사치는 3.148입니다.

# %%
# 총 샘플 수 50,000개
N = 50000

# 정사각형 내에서 무작위 점 생성
x = np.random.uniform(-1, 1, N)
y = np.random.uniform(-1, 1, N)

# 원 안에 있는 점 계산
inside_circle = x**2 + y**2 <= 1

# 원주율 근사값 계산
pi_estimate = 4 * np.sum(inside_circle) / N

print(f"원주율 근사치는 {pi_estimate}입니다.")

# 시각화
plt.figure(figsize=(6,6))
plt.scatter(x, y, c=inside_circle, s=1, alpha=0.5)
plt.gca().set_aspect('equal', adjustable='box')
plt.title(f"원주율 근사치: {pi_estimate}")
plt.show()
# Out:
# 원주율 근사치는 3.13544입니다.

# %%
# 총 샘플 수 100,000개
N = 100000

# 정사각형 내에서 무작위 점 생성
x = np.random.uniform(-1, 1, N)
y = np.random.uniform(-1, 1, N)

# 원 안에 있는 점 계산
inside_circle = x**2 + y**2 <= 1

# 원주율 근사값 계산
pi_estimate = 4 * np.sum(inside_circle) / N

print(f"원주율 근사치는 {pi_estimate}입니다.")

# 시각화
plt.figure(figsize=(6,6))
plt.scatter(x, y, c=inside_circle, s=1, alpha=0.5)
plt.gca().set_aspect('equal', adjustable='box')
plt.title(f"원주율 근사치: {pi_estimate}")
plt.show()
# Out:
# 원주율 근사치는 3.14256입니다.

# %% [markdown]
# # 결론
#
# 이 코드를 실행하면 샘플 크기가 증가할수록 추정된 π 값이 실제 π 값에 가까워지는 것을 관찰할 수 있습니다. 이는 샘플 크기가 증가할수록 표본 평균이 모집단의 평균에 수렴하는 것을 보여주는 '대수의 법칙'을 보여줍니다.
